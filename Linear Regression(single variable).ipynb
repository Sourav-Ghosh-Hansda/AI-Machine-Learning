# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("/Users/souravghoshhansda/Library/CloudStorage/OneDrive-UniversityofEssex/MA336/Practice/linear_regression/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
#scatter plot
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price,color='red',marker='+')
# line plot for area and prediction on area
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg=linear_model.LinearRegression()

reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
#3300 is x
input_value1= [[3300]]
predicted_price1= reg.predict(input_value1)
print("Predicted Price:", predicted_price1)
# Out:
# Predicted Price: [628715.75342466]
# /Users/souravghoshhansda/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#m
reg.coef_
# Out:
# array([135.78767123])

# %%
#intercept
reg.intercept_
# Out:
# 180616.43835616432

# %%
# linear regression formulae y=m*x+b
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
#5000 is x
input_value2= [[5000]]
predicted_price2= reg.predict(input_value2)
print("Predicted Price:", predicted_price2)
# Out:
# Predicted Price: [859554.79452055]
# /Users/souravghoshhansda/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# linear regression formulae y=m*x+b
135.78767123*5000+180616.43835616432
# Out:
# 859554.7945061643

# %%
d=pd.read_csv("/Users/souravghoshhansda/Library/CloudStorage/OneDrive-UniversityofEssex/MA336/Practice/linear_regression/areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d.to_csv("/Users/souravghoshhansda/Library/CloudStorage/OneDrive-UniversityofEssex/MA336/Practice/linear_regression/prediction.csv",index=False)
